# %%
import warnings
import numpy as np
import pandas as pd
import joblib
from sklearn.neural_network import MLPRegressor
from sklearn.metrics import mean_squared_error
from itertools import product
import psutil



warnings.filterwarnings("ignore")

# -----------------------------------------------------------------------------
# CONFIGURACIÓN
# -----------------------------------------------------------------------------
RUTA_DATOS = '/home/cony/Documentos/Cony/trabajo_final/para_subir/datos/datos_sla_y_era.csv'
STEP_DIFF = 1440
LAGS = 0
RUTA_BEST = 'mlp_diff_best.pkl'

# -----------------------------------------------------------------------------
# CARGA Y DIFERENCIACIÓN
# -----------------------------------------------------------------------------
df_raw = (
    pd.read_csv(RUTA_DATOS, parse_dates=['date'])
      .set_index('date')
      .asfreq('1min')
      .interpolate('time')
      .dropna()
)

# Diferenciamos ambas columnas con el mismo paso
df_diff = pd.DataFrame(index=df_raw.index)
df_diff['delta_obs'] = df_raw['Temp'].diff(STEP_DIFF)   # Target
df_diff['delta_era'] = df_raw['t2m'].diff(STEP_DIFF)      # Entrada
df_diff = df_diff.dropna()

COLUMNA_OBJ = 'delta_obs'   # ya no es Temp, es la diferencia
EXOG_COL    = 'delta_era'   # ahora es la diferencia de ERA5

# -----------------------------------------------------------------------------
# FUNCIÓN AUXILIAR – CREAR DATASET
# -----------------------------------------------------------------------------
def make_dataset(df, lags):
    X, y = [], []
    for i in range(lags, len(df)):
        row = df[COLUMNA_OBJ].iloc[i - lags:i].tolist()
        row.append(df[EXOG_COL].iloc[i])
        X.append(row)
        y.append(df[COLUMNA_OBJ].iloc[i])
    return np.array(X), np.array(y)

# -----------------------------------------------------------------------------
# CORTE TRAIN / VAL / TEST
# -----------------------------------------------------------------------------
TOTAL = len(df_diff)
tr_end = int(0.70 * TOTAL)
val_end = int(0.85 * TOTAL)

train_df = df_diff.iloc[:tr_end]
val_df   = df_diff.iloc[tr_end:val_end]
test_df  = df_diff.iloc[val_end:]

X_train, y_train = make_dataset(train_df, LAGS)
X_val,   y_val   = make_dataset(val_df,   LAGS)
X_test,  y_test  = make_dataset(test_df,  LAGS)

print(f"Total: {TOTAL} | Train: {len(y_train)} | Val: {len(y_val)} | Test: {len(y_test)}")
# Out:
# Total: 764681 | Train: 535276 | Val: 114702 | Test: 114703

# %%
# GRID 
# -----------------------------------------------------------------------------
grid = {
    'hidden_layer_sizes': [(4,), (8,), (8, 4), (8, 8)],
    'activation': ['relu', 'tanh', 'logistic'],
    'alpha': [1e-2, 1e-1, 1],         # defecto 1e-4, mayor alpha menor riesgo de sobreajuste
    'learning_rate_init': [1e-3, 1e-2],
    'max_iter': [80, 100],
    'early_stopping': [True],
    'n_iter_no_change': [7],
}


best_val_rmse = np.inf
best_model = None
best_params = None


# -----------------------------------------------------------------------------
print("\nIniciando grid-search sobre validación...")
combinaciones = list(product(
    grid['hidden_layer_sizes'],
    grid['activation'],
    grid['alpha'],
    grid['learning_rate_init'],
    grid['max_iter']))
print(f"Total de combinaciones: {len(combinaciones)}\n")

best_val_mse = np.inf
best_model   = None
best_params  = None

for idx, (hs, act, alpha, lr, it) in enumerate(combinaciones, 1):
    tic = pd.Timestamp.now()
    mlp = MLPRegressor(
        hidden_layer_sizes=hs,
        activation=act,
        alpha=alpha,
        learning_rate_init=lr,
        max_iter=it,
        solver='adam',
        random_state=42,
        early_stopping=True,
        n_iter_no_change=10
    )
    mlp.fit(X_train, y_train)
    val_pred = mlp.predict(X_val)
    val_mse  = mean_squared_error(y_val, val_pred)
    mem      = psutil.Process().memory_info().rss / 1024**2
    elapsed  = (pd.Timestamp.now() - tic).total_seconds()
    print(f"[{idx:>3}/{len(combinaciones)}] "
          f"{hs}-{act}-α{alpha} - lr{lr} - it{it} |  act: {act}"
          f" MSE: {val_mse:.4f} | RAM: {mem:.1f} MiB | {elapsed:.1f}s")

    if val_mse < best_val_mse:
        best_val_mse, best_model, best_params = val_mse, mlp, {
            'hidden_layer_sizes': hs,
            'activation': act,
            'alpha': alpha,
            'learning_rate_init': lr,
            'max_iter': it
        }
    train_pred = mlp.predict(X_train)
    train_mse  = mean_squared_error(y_train, train_pred)
    print(f"  → MSE train: {train_mse:.4f} | MSE val: {val_mse:.4f}")
    

joblib.dump(best_model, RUTA_BEST)
print("Mejores hiper-parámetros:", best_params)
print("MSE en val:", best_val_mse)
# Out:
# Iniciando grid-search sobre validación...
# Total de combinaciones: 144
#
# [  1/144] (4,)-relu-α0.01 - lr0.001 - it80 |  act: relu MSE: 7.7117 | RAM: 278.7 MiB | 26.5s
#   → MSE train: 4.9582 | MSE val: 7.7117
# [  2/144] (4,)-relu-α0.01 - lr0.001 - it100 |  act: relu MSE: 7.7117 | RAM: 286.6 MiB | 25.8s
#   → MSE train: 4.9582 | MSE val: 7.7117
# [  3/144] (4,)-relu-α0.01 - lr0.01 - it80 |  act: relu MSE: 7.7500 | RAM: 288.1 MiB | 12.0s
#   → MSE train: 4.9560 | MSE val: 7.7500
# [  4/144] (4,)-relu-α0.01 - lr0.01 - it100 |  act: relu MSE: 7.7500 | RAM: 288.1 MiB | 11.7s
#   → MSE train: 4.9560 | MSE val: 7.7500
# [  5/144] (4,)-relu-α0.1 - lr0.001 - it80 |  act: relu MSE: 7.6860 | RAM: 288.1 MiB | 22.0s
#   → MSE train: 4.9594 | MSE val: 7.6860
# [  6/144] (4,)-relu-α0.1 - lr0.001 - it100 |  act: relu MSE: 7.6860 | RAM: 288.1 MiB | 22.0s
#   → MSE train: 4.9594 | MSE val: 7.6860
# [  7/144] (4,)-relu-α0.1 - lr0.01 - it80 |  act: relu MSE: 7.6932 | RAM: 288.1 MiB | 11.8s
#   → MSE train: 4.9542 | MSE val: 7.6932
# [  8/144] (4,)-relu-α0.1 - lr0.01 - it100 |  act: relu MSE: 7.6932 | RAM: 288.1 MiB | 11.6s
#   → MSE train: 4.9542 | MSE val: 7.6932
# [  9/144] (4,)-relu-α1 - lr0.001 - it80 |  act: relu MSE: 7.6178 | RAM: 288.1 MiB | 22.3s
#   → MSE train: 4.9651 | MSE val: 7.6178
# [ 10/144] (4,)-relu-α1 - lr0.001 - it100 |  act: relu MSE: 7.6178 | RAM: 288.1 MiB | 22.6s
#   → MSE train: 4.9651 | MSE val: 7.6178
# [ 11/144] (4,)-relu-α1 - lr0.01 - it80 |  act: relu MSE: 7.6031 | RAM: 288.1 MiB | 10.0s
#   → MSE train: 4.9585 | MSE val: 7.6031
# [ 12/144] (4,)-relu-α1 - lr0.01 - it100 |  act: relu MSE: 7.6031 | RAM: 288.1 MiB | 10.1s
#   → MSE train: 4.9585 | MSE val: 7.6031
# [ 13/144] (4,)-tanh-α0.01 - lr0.001 - it80 |  act: tanh MSE: 7.5539 | RAM: 288.1 MiB | 13.2s
#   → MSE train: 4.8927 | MSE val: 7.5539
# [ 14/144] (4,)-tanh-α0.01 - lr0.001 - it100 |  act: tanh MSE: 7.5539 | RAM: 288.1 MiB | 13.2s
#   → MSE train: 4.8927 | MSE val: 7.5539
# [ 15/144] (4,)-tanh-α0.01 - lr0.01 - it80 |  act: tanh MSE: 7.5313 | RAM: 288.1 MiB | 8.8s
#   → MSE train: 4.8884 | MSE val: 7.5313
# [ 16/144] (4,)-tanh-α0.01 - lr0.01 - it100 |  act: tanh MSE: 7.5313 | RAM: 288.1 MiB | 8.8s
#   → MSE train: 4.8884 | MSE val: 7.5313
# [ 17/144] (4,)-tanh-α0.1 - lr0.001 - it80 |  act: tanh MSE: 7.5011 | RAM: 288.1 MiB | 13.3s
#   → MSE train: 4.8978 | MSE val: 7.5011
# [ 18/144] (4,)-tanh-α0.1 - lr0.001 - it100 |  act: tanh MSE: 7.5011 | RAM: 288.1 MiB | 13.3s
#   → MSE train: 4.8978 | MSE val: 7.5011
# [ 19/144] (4,)-tanh-α0.1 - lr0.01 - it80 |  act: tanh MSE: 7.5377 | RAM: 288.1 MiB | 8.8s
#   → MSE train: 4.8898 | MSE val: 7.5377
# [ 20/144] (4,)-tanh-α0.1 - lr0.01 - it100 |  act: tanh MSE: 7.5377 | RAM: 288.1 MiB | 8.8s
#   → MSE train: 4.8898 | MSE val: 7.5377
# [ 21/144] (4,)-tanh-α1 - lr0.001 - it80 |  act: tanh MSE: 7.6273 | RAM: 288.1 MiB | 20.4s
#   → MSE train: 4.9183 | MSE val: 7.6273
# [ 22/144] (4,)-tanh-α1 - lr0.001 - it100 |  act: tanh MSE: 7.6273 | RAM: 288.1 MiB | 20.3s
#   → MSE train: 4.9183 | MSE val: 7.6273
# [ 23/144] (4,)-tanh-α1 - lr0.01 - it80 |  act: tanh MSE: 7.6791 | RAM: 288.1 MiB | 7.1s
#   → MSE train: 4.9298 | MSE val: 7.6791
# [ 24/144] (4,)-tanh-α1 - lr0.01 - it100 |  act: tanh MSE: 7.6791 | RAM: 288.1 MiB | 7.2s
#   → MSE train: 4.9298 | MSE val: 7.6791
# [ 25/144] (4,)-logistic-α0.01 - lr0.001 - it80 |  act: logistic MSE: 7.5163 | RAM: 288.1 MiB | 20.8s
#   → MSE train: 4.8904 | MSE val: 7.5163
# [ 26/144] (4,)-logistic-α0.01 - lr0.001 - it100 |  act: logistic MSE: 7.5163 | RAM: 288.1 MiB | 20.8s
#   → MSE train: 4.8904 | MSE val: 7.5163
# [ 27/144] (4,)-logistic-α0.01 - lr0.01 - it80 |  act: logistic MSE: 7.5092 | RAM: 288.1 MiB | 11.9s
#   → MSE train: 4.8904 | MSE val: 7.5092
# [ 28/144] (4,)-logistic-α0.01 - lr0.01 - it100 |  act: logistic MSE: 7.5092 | RAM: 288.1 MiB | 11.6s
#   → MSE train: 4.8904 | MSE val: 7.5092
# [ 29/144] (4,)-logistic-α0.1 - lr0.001 - it80 |  act: logistic MSE: 7.5724 | RAM: 288.1 MiB | 19.8s
#   → MSE train: 4.8994 | MSE val: 7.5724
# [ 30/144] (4,)-logistic-α0.1 - lr0.001 - it100 |  act: logistic MSE: 7.5724 | RAM: 288.1 MiB | 19.7s
#   → MSE train: 4.8994 | MSE val: 7.5724
# [ 31/144] (4,)-logistic-α0.1 - lr0.01 - it80 |  act: logistic MSE: 7.5837 | RAM: 288.1 MiB | 12.0s
#   → MSE train: 4.8974 | MSE val: 7.5837
# [ 32/144] (4,)-logistic-α0.1 - lr0.01 - it100 |  act: logistic MSE: 7.5837 | RAM: 288.1 MiB | 11.7s
#   → MSE train: 4.8974 | MSE val: 7.5837
# [ 33/144] (4,)-logistic-α1 - lr0.001 - it80 |  act: logistic MSE: 7.7732 | RAM: 288.1 MiB | 17.3s
#   → MSE train: 5.0712 | MSE val: 7.7732
# [ 34/144] (4,)-logistic-α1 - lr0.001 - it100 |  act: logistic MSE: 7.7732 | RAM: 288.1 MiB | 17.8s
#   → MSE train: 5.0712 | MSE val: 7.7732
# [ 35/144] (4,)-logistic-α1 - lr0.01 - it80 |  act: logistic MSE: 7.7218 | RAM: 288.1 MiB | 11.8s
#   → MSE train: 5.0564 | MSE val: 7.7218
# [ 36/144] (4,)-logistic-α1 - lr0.01 - it100 |  act: logistic MSE: 7.7218 | RAM: 288.1 MiB | 11.6s
#   → MSE train: 5.0564 | MSE val: 7.7218
# [ 37/144] (8,)-relu-α0.01 - lr0.001 - it80 |  act: relu MSE: 7.4045 | RAM: 288.1 MiB | 10.1s
#   → MSE train: 4.8982 | MSE val: 7.4045
# [ 38/144] (8,)-relu-α0.01 - lr0.001 - it100 |  act: relu MSE: 7.4045 | RAM: 288.3 MiB | 9.9s
#   → MSE train: 4.8982 | MSE val: 7.4045
# [ 39/144] (8,)-relu-α0.01 - lr0.01 - it80 |  act: relu MSE: 7.3723 | RAM: 288.3 MiB | 7.8s
#   → MSE train: 4.9012 | MSE val: 7.3723
# [ 40/144] (8,)-relu-α0.01 - lr0.01 - it100 |  act: relu MSE: 7.3723 | RAM: 288.3 MiB | 7.6s
#   → MSE train: 4.9012 | MSE val: 7.3723
# [ 41/144] (8,)-relu-α0.1 - lr0.001 - it80 |  act: relu MSE: 7.4049 | RAM: 288.3 MiB | 10.0s
#   → MSE train: 4.8981 | MSE val: 7.4049
# [ 42/144] (8,)-relu-α0.1 - lr0.001 - it100 |  act: relu MSE: 7.4049 | RAM: 288.3 MiB | 10.1s
#   → MSE train: 4.8981 | MSE val: 7.4049
# [ 43/144] (8,)-relu-α0.1 - lr0.01 - it80 |  act: relu MSE: 7.3739 | RAM: 288.3 MiB | 7.8s
#   → MSE train: 4.9011 | MSE val: 7.3739
# [ 44/144] (8,)-relu-α0.1 - lr0.01 - it100 |  act: relu MSE: 7.3739 | RAM: 288.3 MiB | 7.9s
#   → MSE train: 4.9011 | MSE val: 7.3739
# [ 45/144] (8,)-relu-α1 - lr0.001 - it80 |  act: relu MSE: 7.4072 | RAM: 288.3 MiB | 10.2s
#   → MSE train: 4.8981 | MSE val: 7.4072
# [ 46/144] (8,)-relu-α1 - lr0.001 - it100 |  act: relu MSE: 7.4072 | RAM: 288.3 MiB | 10.1s
#   → MSE train: 4.8981 | MSE val: 7.4072
# [ 47/144] (8,)-relu-α1 - lr0.01 - it80 |  act: relu MSE: 7.3707 | RAM: 288.3 MiB | 7.7s
#   → MSE train: 4.9015 | MSE val: 7.3707
# [ 48/144] (8,)-relu-α1 - lr0.01 - it100 |  act: relu MSE: 7.3707 | RAM: 288.3 MiB | 7.9s
#   → MSE train: 4.9015 | MSE val: 7.3707
# [ 49/144] (8,)-tanh-α0.01 - lr0.001 - it80 |  act: tanh MSE: 7.5026 | RAM: 288.3 MiB | 22.8s
#   → MSE train: 4.8883 | MSE val: 7.5026
# [ 50/144] (8,)-tanh-α0.01 - lr0.001 - it100 |  act: tanh MSE: 7.5026 | RAM: 288.3 MiB | 23.0s
#   → MSE train: 4.8883 | MSE val: 7.5026
# [ 51/144] (8,)-tanh-α0.01 - lr0.01 - it80 |  act: tanh MSE: 7.5890 | RAM: 288.3 MiB | 13.2s
#   → MSE train: 4.8795 | MSE val: 7.5890
# [ 52/144] (8,)-tanh-α0.01 - lr0.01 - it100 |  act: tanh MSE: 7.5890 | RAM: 288.3 MiB | 13.3s
#   → MSE train: 4.8795 | MSE val: 7.5890
# [ 53/144] (8,)-tanh-α0.1 - lr0.001 - it80 |  act: tanh MSE: 7.5076 | RAM: 288.3 MiB | 18.9s
#   → MSE train: 4.8900 | MSE val: 7.5076
# [ 54/144] (8,)-tanh-α0.1 - lr0.001 - it100 |  act: tanh MSE: 7.5076 | RAM: 288.3 MiB | 18.9s
#   → MSE train: 4.8900 | MSE val: 7.5076
# [ 55/144] (8,)-tanh-α0.1 - lr0.01 - it80 |  act: tanh MSE: 7.5864 | RAM: 288.3 MiB | 13.2s
#   → MSE train: 4.8804 | MSE val: 7.5864
# [ 56/144] (8,)-tanh-α0.1 - lr0.01 - it100 |  act: tanh MSE: 7.5864 | RAM: 288.3 MiB | 13.2s
#   → MSE train: 4.8804 | MSE val: 7.5864
# [ 57/144] (8,)-tanh-α1 - lr0.001 - it80 |  act: tanh MSE: 7.5697 | RAM: 288.3 MiB | 19.0s
#   → MSE train: 4.9036 | MSE val: 7.5697
# [ 58/144] (8,)-tanh-α1 - lr0.001 - it100 |  act: tanh MSE: 7.5697 | RAM: 288.3 MiB | 18.7s
#   → MSE train: 4.9036 | MSE val: 7.5697
# [ 59/144] (8,)-tanh-α1 - lr0.01 - it80 |  act: tanh MSE: 7.7245 | RAM: 288.3 MiB | 13.2s
#   → MSE train: 4.9022 | MSE val: 7.7245
# [ 60/144] (8,)-tanh-α1 - lr0.01 - it100 |  act: tanh MSE: 7.7245 | RAM: 288.3 MiB | 13.1s
#   → MSE train: 4.9022 | MSE val: 7.7245
# [ 61/144] (8,)-logistic-α0.01 - lr0.001 - it80 |  act: logistic MSE: 7.5115 | RAM: 288.3 MiB | 19.2s
#   → MSE train: 4.8925 | MSE val: 7.5115
# [ 62/144] (8,)-logistic-α0.01 - lr0.001 - it100 |  act: logistic MSE: 7.5115 | RAM: 288.3 MiB | 19.2s
#   → MSE train: 4.8925 | MSE val: 7.5115
# [ 63/144] (8,)-logistic-α0.01 - lr0.01 - it80 |  act: logistic MSE: 7.5089 | RAM: 288.3 MiB | 7.9s
#   → MSE train: 4.8842 | MSE val: 7.5089
# [ 64/144] (8,)-logistic-α0.01 - lr0.01 - it100 |  act: logistic MSE: 7.5089 | RAM: 288.3 MiB | 7.9s
#   → MSE train: 4.8842 | MSE val: 7.5089
# [ 65/144] (8,)-logistic-α0.1 - lr0.001 - it80 |  act: logistic MSE: 7.5256 | RAM: 288.3 MiB | 16.6s
#   → MSE train: 4.8947 | MSE val: 7.5256
# [ 66/144] (8,)-logistic-α0.1 - lr0.001 - it100 |  act: logistic MSE: 7.5256 | RAM: 288.3 MiB | 16.5s
#   → MSE train: 4.8947 | MSE val: 7.5256
# [ 67/144] (8,)-logistic-α0.1 - lr0.01 - it80 |  act: logistic MSE: 7.5311 | RAM: 288.3 MiB | 7.8s
#   → MSE train: 4.8879 | MSE val: 7.5311
# [ 68/144] (8,)-logistic-α0.1 - lr0.01 - it100 |  act: logistic MSE: 7.5311 | RAM: 288.3 MiB | 7.8s
#   → MSE train: 4.8879 | MSE val: 7.5311
# [ 69/144] (8,)-logistic-α1 - lr0.001 - it80 |  act: logistic MSE: 7.6910 | RAM: 288.3 MiB | 20.1s
#   → MSE train: 4.9660 | MSE val: 7.6910
# [ 70/144] (8,)-logistic-α1 - lr0.001 - it100 |  act: logistic MSE: 7.6910 | RAM: 288.3 MiB | 20.0s
#   → MSE train: 4.9660 | MSE val: 7.6910
# [ 71/144] (8,)-logistic-α1 - lr0.01 - it80 |  act: logistic MSE: 7.6352 | RAM: 288.3 MiB | 16.7s
#   → MSE train: 4.9534 | MSE val: 7.6352
# [ 72/144] (8,)-logistic-α1 - lr0.01 - it100 |  act: logistic MSE: 7.6352 | RAM: 288.3 MiB | 16.7s
#   → MSE train: 4.9534 | MSE val: 7.6352
# [ 73/144] (8, 4)-relu-α0.01 - lr0.001 - it80 |  act: relu MSE: 7.3851 | RAM: 296.1 MiB | 19.4s
#   → MSE train: 4.8989 | MSE val: 7.3851
# [ 74/144] (8, 4)-relu-α0.01 - lr0.001 - it100 |  act: relu MSE: 7.3851 | RAM: 301.8 MiB | 19.5s
#   → MSE train: 4.8989 | MSE val: 7.3851
# [ 75/144] (8, 4)-relu-α0.01 - lr0.01 - it80 |  act: relu MSE: 7.4206 | RAM: 301.8 MiB | 26.5s
#   → MSE train: 4.9017 | MSE val: 7.4206
# [ 76/144] (8, 4)-relu-α0.01 - lr0.01 - it100 |  act: relu MSE: 7.4206 | RAM: 301.8 MiB | 26.6s
#   → MSE train: 4.9017 | MSE val: 7.4206
# [ 77/144] (8, 4)-relu-α0.1 - lr0.001 - it80 |  act: relu MSE: 7.3906 | RAM: 301.8 MiB | 16.9s
#   → MSE train: 4.8989 | MSE val: 7.3906
# [ 78/144] (8, 4)-relu-α0.1 - lr0.001 - it100 |  act: relu MSE: 7.3906 | RAM: 301.8 MiB | 16.9s
#   → MSE train: 4.8989 | MSE val: 7.3906
# [ 79/144] (8, 4)-relu-α0.1 - lr0.01 - it80 |  act: relu MSE: 7.3849 | RAM: 301.8 MiB | 12.6s
#   → MSE train: 4.9120 | MSE val: 7.3849
# [ 80/144] (8, 4)-relu-α0.1 - lr0.01 - it100 |  act: relu MSE: 7.3849 | RAM: 301.8 MiB | 12.7s
#   → MSE train: 4.9120 | MSE val: 7.3849
# [ 81/144] (8, 4)-relu-α1 - lr0.001 - it80 |  act: relu MSE: 7.4404 | RAM: 301.8 MiB | 20.1s
#   → MSE train: 4.8873 | MSE val: 7.4404
# [ 82/144] (8, 4)-relu-α1 - lr0.001 - it100 |  act: relu MSE: 7.4404 | RAM: 301.8 MiB | 19.5s
#   → MSE train: 4.8873 | MSE val: 7.4404
# [ 83/144] (8, 4)-relu-α1 - lr0.01 - it80 |  act: relu MSE: 7.4008 | RAM: 301.8 MiB | 12.5s
#   → MSE train: 4.9083 | MSE val: 7.4008
# [ 84/144] (8, 4)-relu-α1 - lr0.01 - it100 |  act: relu MSE: 7.4008 | RAM: 301.8 MiB | 12.6s
#   → MSE train: 4.9083 | MSE val: 7.4008
# [ 85/144] (8, 4)-tanh-α0.01 - lr0.001 - it80 |  act: tanh MSE: 7.5035 | RAM: 301.8 MiB | 22.2s
#   → MSE train: 4.8824 | MSE val: 7.5035
# [ 86/144] (8, 4)-tanh-α0.01 - lr0.001 - it100 |  act: tanh MSE: 7.5035 | RAM: 301.8 MiB | 22.4s
#   → MSE train: 4.8824 | MSE val: 7.5035
# [ 87/144] (8, 4)-tanh-α0.01 - lr0.01 - it80 |  act: tanh MSE: 7.6622 | RAM: 301.8 MiB | 10.2s
#   → MSE train: 4.9052 | MSE val: 7.6622
# [ 88/144] (8, 4)-tanh-α0.01 - lr0.01 - it100 |  act: tanh MSE: 7.6622 | RAM: 301.8 MiB | 10.0s
#   → MSE train: 4.9052 | MSE val: 7.6622
# [ 89/144] (8, 4)-tanh-α0.1 - lr0.001 - it80 |  act: tanh MSE: 7.5025 | RAM: 301.8 MiB | 22.8s
#   → MSE train: 4.8853 | MSE val: 7.5025
# [ 90/144] (8, 4)-tanh-α0.1 - lr0.001 - it100 |  act: tanh MSE: 7.5025 | RAM: 301.8 MiB | 22.2s
#   → MSE train: 4.8853 | MSE val: 7.5025
# [ 91/144] (8, 4)-tanh-α0.1 - lr0.01 - it80 |  act: tanh MSE: 7.5064 | RAM: 301.8 MiB | 9.3s
#   → MSE train: 4.9010 | MSE val: 7.5064
# [ 92/144] (8, 4)-tanh-α0.1 - lr0.01 - it100 |  act: tanh MSE: 7.5064 | RAM: 301.8 MiB | 9.4s
#   → MSE train: 4.9010 | MSE val: 7.5064
# [ 93/144] (8, 4)-tanh-α1 - lr0.001 - it80 |  act: tanh MSE: 7.5978 | RAM: 301.8 MiB | 27.9s
#   → MSE train: 4.9207 | MSE val: 7.5978
# [ 94/144] (8, 4)-tanh-α1 - lr0.001 - it100 |  act: tanh MSE: 7.5978 | RAM: 301.8 MiB | 27.8s
#   → MSE train: 4.9207 | MSE val: 7.5978
# [ 95/144] (8, 4)-tanh-α1 - lr0.01 - it80 |  act: tanh MSE: 7.7477 | RAM: 301.8 MiB | 10.0s
#   → MSE train: 4.9410 | MSE val: 7.7477
# [ 96/144] (8, 4)-tanh-α1 - lr0.01 - it100 |  act: tanh MSE: 7.7477 | RAM: 301.8 MiB | 10.1s
#   → MSE train: 4.9410 | MSE val: 7.7477
# [ 97/144] (8, 4)-logistic-α0.01 - lr0.001 - it80 |  act: logistic MSE: 7.5266 | RAM: 301.8 MiB | 34.2s
#   → MSE train: 4.8984 | MSE val: 7.5266
# [ 98/144] (8, 4)-logistic-α0.01 - lr0.001 - it100 |  act: logistic MSE: 7.5266 | RAM: 301.8 MiB | 34.5s
#   → MSE train: 4.8984 | MSE val: 7.5266
# [ 99/144] (8, 4)-logistic-α0.01 - lr0.01 - it80 |  act: logistic MSE: 7.6234 | RAM: 301.8 MiB | 27.5s
#   → MSE train: 4.8849 | MSE val: 7.6234
# [100/144] (8, 4)-logistic-α0.01 - lr0.01 - it100 |  act: logistic MSE: 7.6234 | RAM: 301.8 MiB | 27.8s
#   → MSE train: 4.8849 | MSE val: 7.6234
# [101/144] (8, 4)-logistic-α0.1 - lr0.001 - it80 |  act: logistic MSE: 7.5829 | RAM: 301.8 MiB | 38.5s
#   → MSE train: 4.9043 | MSE val: 7.5829
# [102/144] (8, 4)-logistic-α0.1 - lr0.001 - it100 |  act: logistic MSE: 7.5829 | RAM: 301.8 MiB | 38.5s
#   → MSE train: 4.9043 | MSE val: 7.5829
# [103/144] (8, 4)-logistic-α0.1 - lr0.01 - it80 |  act: logistic MSE: 7.5959 | RAM: 301.8 MiB | 23.6s
#   → MSE train: 4.8884 | MSE val: 7.5959
# [104/144] (8, 4)-logistic-α0.1 - lr0.01 - it100 |  act: logistic MSE: 7.5959 | RAM: 301.8 MiB | 23.4s
#   → MSE train: 4.8884 | MSE val: 7.5959
# [105/144] (8, 4)-logistic-α1 - lr0.001 - it80 |  act: logistic MSE: 7.8003 | RAM: 301.8 MiB | 44.7s
#   → MSE train: 5.0916 | MSE val: 7.8003
# [106/144] (8, 4)-logistic-α1 - lr0.001 - it100 |  act: logistic MSE: 7.8003 | RAM: 301.8 MiB | 44.6s
#   → MSE train: 5.0916 | MSE val: 7.8003
# [107/144] (8, 4)-logistic-α1 - lr0.01 - it80 |  act: logistic MSE: 7.8074 | RAM: 301.8 MiB | 19.1s
#   → MSE train: 5.0849 | MSE val: 7.8074
# [108/144] (8, 4)-logistic-α1 - lr0.01 - it100 |  act: logistic MSE: 7.8074 | RAM: 301.8 MiB | 19.2s
#   → MSE train: 5.0849 | MSE val: 7.8074
# [109/144] (8, 8)-relu-α0.01 - lr0.001 - it80 |  act: relu MSE: 7.3927 | RAM: 302.3 MiB | 10.5s
#   → MSE train: 4.9000 | MSE val: 7.3927
# [110/144] (8, 8)-relu-α0.01 - lr0.001 - it100 |  act: relu MSE: 7.3927 | RAM: 302.7 MiB | 10.6s
#   → MSE train: 4.9000 | MSE val: 7.3927
# [111/144] (8, 8)-relu-α0.01 - lr0.01 - it80 |  act: relu MSE: 7.4284 | RAM: 302.9 MiB | 8.5s
#   → MSE train: 4.9057 | MSE val: 7.4284
# [112/144] (8, 8)-relu-α0.01 - lr0.01 - it100 |  act: relu MSE: 7.4284 | RAM: 303.1 MiB | 8.6s
#   → MSE train: 4.9057 | MSE val: 7.4284
# [113/144] (8, 8)-relu-α0.1 - lr0.001 - it80 |  act: relu MSE: 7.4048 | RAM: 303.3 MiB | 10.4s
#   → MSE train: 4.8976 | MSE val: 7.4048
# [114/144] (8, 8)-relu-α0.1 - lr0.001 - it100 |  act: relu MSE: 7.4048 | RAM: 303.5 MiB | 10.5s
#   → MSE train: 4.8976 | MSE val: 7.4048
# [115/144] (8, 8)-relu-α0.1 - lr0.01 - it80 |  act: relu MSE: 7.3564 | RAM: 303.5 MiB | 8.4s
#   → MSE train: 4.9075 | MSE val: 7.3564
# [116/144] (8, 8)-relu-α0.1 - lr0.01 - it100 |  act: relu MSE: 7.3564 | RAM: 302.9 MiB | 8.5s
#   → MSE train: 4.9075 | MSE val: 7.3564
# [117/144] (8, 8)-relu-α1 - lr0.001 - it80 |  act: relu MSE: 7.4089 | RAM: 302.6 MiB | 8.4s
#   → MSE train: 4.8992 | MSE val: 7.4089
# [118/144] (8, 8)-relu-α1 - lr0.001 - it100 |  act: relu MSE: 7.4089 | RAM: 302.7 MiB | 8.7s
#   → MSE train: 4.8992 | MSE val: 7.4089
# [119/144] (8, 8)-relu-α1 - lr0.01 - it80 |  act: relu MSE: 7.4408 | RAM: 302.9 MiB | 8.6s
#   → MSE train: 4.9060 | MSE val: 7.4408
# [120/144] (8, 8)-relu-α1 - lr0.01 - it100 |  act: relu MSE: 7.4408 | RAM: 303.1 MiB | 8.5s
#   → MSE train: 4.9060 | MSE val: 7.4408
# [121/144] (8, 8)-tanh-α0.01 - lr0.001 - it80 |  act: tanh MSE: 7.5405 | RAM: 303.3 MiB | 24.0s
#   → MSE train: 4.8801 | MSE val: 7.5405
# [122/144] (8, 8)-tanh-α0.01 - lr0.001 - it100 |  act: tanh MSE: 7.5405 | RAM: 303.3 MiB | 24.5s
#   → MSE train: 4.8801 | MSE val: 7.5405
# [123/144] (8, 8)-tanh-α0.01 - lr0.01 - it80 |  act: tanh MSE: 7.6019 | RAM: 303.2 MiB | 12.0s
#   → MSE train: 4.8839 | MSE val: 7.6019
# [124/144] (8, 8)-tanh-α0.01 - lr0.01 - it100 |  act: tanh MSE: 7.6019 | RAM: 303.1 MiB | 12.0s
#   → MSE train: 4.8839 | MSE val: 7.6019
# [125/144] (8, 8)-tanh-α0.1 - lr0.001 - it80 |  act: tanh MSE: 7.5520 | RAM: 303.1 MiB | 19.1s
#   → MSE train: 4.8850 | MSE val: 7.5520
# [126/144] (8, 8)-tanh-α0.1 - lr0.001 - it100 |  act: tanh MSE: 7.5520 | RAM: 302.8 MiB | 18.7s
#   → MSE train: 4.8850 | MSE val: 7.5520
# [127/144] (8, 8)-tanh-α0.1 - lr0.01 - it80 |  act: tanh MSE: 7.5998 | RAM: 302.7 MiB | 10.2s
#   → MSE train: 4.8865 | MSE val: 7.5998
# [128/144] (8, 8)-tanh-α0.1 - lr0.01 - it100 |  act: tanh MSE: 7.5998 | RAM: 302.8 MiB | 10.9s
#   → MSE train: 4.8865 | MSE val: 7.5998
# [129/144] (8, 8)-tanh-α1 - lr0.001 - it80 |  act: tanh MSE: 7.5645 | RAM: 303.0 MiB | 35.7s
#   → MSE train: 4.9005 | MSE val: 7.5645
# [130/144] (8, 8)-tanh-α1 - lr0.001 - it100 |  act: tanh MSE: 7.5645 | RAM: 303.2 MiB | 35.8s
#   → MSE train: 4.9005 | MSE val: 7.5645
# [131/144] (8, 8)-tanh-α1 - lr0.01 - it80 |  act: tanh MSE: 7.5489 | RAM: 303.2 MiB | 19.6s
#   → MSE train: 4.8989 | MSE val: 7.5489
# [132/144] (8, 8)-tanh-α1 - lr0.01 - it100 |  act: tanh MSE: 7.5489 | RAM: 303.1 MiB | 19.7s
#   → MSE train: 4.8989 | MSE val: 7.5489
# [133/144] (8, 8)-logistic-α0.01 - lr0.001 - it80 |  act: logistic MSE: 7.4786 | RAM: 303.1 MiB | 31.7s
#   → MSE train: 4.8899 | MSE val: 7.4786
# [134/144] (8, 8)-logistic-α0.01 - lr0.001 - it100 |  act: logistic MSE: 7.4786 | RAM: 303.2 MiB | 31.3s
#   → MSE train: 4.8899 | MSE val: 7.4786
# [135/144] (8, 8)-logistic-α0.01 - lr0.01 - it80 |  act: logistic MSE: 7.5748 | RAM: 302.9 MiB | 30.1s
#   → MSE train: 4.8802 | MSE val: 7.5748
# [136/144] (8, 8)-logistic-α0.01 - lr0.01 - it100 |  act: logistic MSE: 7.5748 | RAM: 302.9 MiB | 30.0s
#   → MSE train: 4.8802 | MSE val: 7.5748
# [137/144] (8, 8)-logistic-α0.1 - lr0.001 - it80 |  act: logistic MSE: 7.5449 | RAM: 303.0 MiB | 54.8s
#   → MSE train: 4.8908 | MSE val: 7.5449
# [138/144] (8, 8)-logistic-α0.1 - lr0.001 - it100 |  act: logistic MSE: 7.5449 | RAM: 303.2 MiB | 55.4s
#   → MSE train: 4.8908 | MSE val: 7.5449
# [139/144] (8, 8)-logistic-α0.1 - lr0.01 - it80 |  act: logistic MSE: 7.6162 | RAM: 303.1 MiB | 12.6s
#   → MSE train: 4.8970 | MSE val: 7.6162
# [140/144] (8, 8)-logistic-α0.1 - lr0.01 - it100 |  act: logistic MSE: 7.6162 | RAM: 303.3 MiB | 12.7s
#   → MSE train: 4.8970 | MSE val: 7.6162
# [141/144] (8, 8)-logistic-α1 - lr0.001 - it80 |  act: logistic MSE: 7.7047 | RAM: 303.3 MiB | 45.6s
#   → MSE train: 4.9977 | MSE val: 7.7047
# [142/144] (8, 8)-logistic-α1 - lr0.001 - it100 |  act: logistic MSE: 7.7047 | RAM: 303.0 MiB | 45.2s
#   → MSE train: 4.9977 | MSE val: 7.7047
# [143/144] (8, 8)-logistic-α1 - lr0.01 - it80 |  act: logistic MSE: 7.7174 | RAM: 303.1 MiB | 20.5s
#   → MSE train: 4.9932 | MSE val: 7.7174
# [144/144] (8, 8)-logistic-α1 - lr0.01 - it100 |  act: logistic MSE: 7.7174 | RAM: 302.8 MiB | 20.0s
#   → MSE train: 4.9932 | MSE val: 7.7174
# Mejores hiper-parámetros: {'hidden_layer_sizes': (8, 8), 'activation': 'relu', 'alpha': 0.1, 'learning_rate_init': 0.01, 'max_iter': 80}
# MSE en val: 7.356438738649259

# %%
import pandas as pd, matplotlib.pyplot as plt, sys
ruta_directorio = r'/home/cony/Documentos/GEERS/codigos_pc'
sys.path.append(ruta_directorio)
import Metrics as m

# --- funciones limpias -------------------------------------------
def plots(x, y_original, y_estimado, serie='serie'):
    plt.figure(figsize=(14,4))
    plt.plot(x, y_original, label=f'{serie} original')
    plt.plot(x, y_estimado, label=f'{serie} estimado')
    plt.xlabel('Etiqueta temporal', fontsize=15)
    plt.ylabel('T (°C)', fontsize=15)
    plt.xticks(fontsize=15)
    plt.yticks(fontsize=15)
    plt.legend(fontsize=20)
    plt.tight_layout()
    plt.grid(True)
    plt.show()

def calculo_m(true, pred):
    rmbe  = m.rmbe(true, pred)
    rrmsd = m.rrmsd(true, pred)
    rmae  = m.rmae(true, pred)
    return rmbe, rrmsd, rmae

# %%
# %matplotlib qt
# -----------------------------------------------------------------------------
# 1)  TEST
# -----------------------------------------------------------------------------
test_idx   = test_df.index
base_test  = df_raw['Temp'].shift(STEP_DIFF).loc[test_idx]
delta_pred = best_model.predict(X_test)

df_pred = pd.DataFrame(index=test_idx)
df_pred['Temp']      = base_test + delta_pred
df_pred['y_pred']    = df_pred['Temp']          # mismo valor, alias para tu función
df_pred['y_true']    = df_raw['Temp'].loc[test_idx]

rmbe_test, rrmsd_test, rmae_test = calculo_m(df_pred['y_true'], df_pred['y_pred'])
print("\n=== TEST (reconstruido) ===")
print(f"rMBE:  {rmbe_test:.4f}%")
print(f"rRMSD: {rrmsd_test:.4f}%")
print(f"rMAE:  {rmae_test:.4f}%")

plots(df_pred.index, df_pred['y_true'], df_pred['y_pred'], serie='Test')

# -----------------------------------------------------------------------------
# 2)  ENTRENAMIENTO
# -----------------------------------------------------------------------------
train_idx   = train_df.index
base_train  = df_raw['Temp'].shift(STEP_DIFF).loc[train_idx]
delta_pred_train = best_model.predict(X_train)

df_pred_train = pd.DataFrame(index=train_idx)
df_pred_train['Temp']      = base_train + delta_pred_train
df_pred_train['y_pred']    = df_pred_train['Temp']
df_pred_train['y_true']    = df_raw['Temp'].loc[train_idx]

rmbe_train, rrmsd_train, rmae_train = calculo_m(
    df_pred_train['y_true'], df_pred_train['y_pred'])

print("\n=== ENTRENAMIENTO (reconstruido) ===")
print(f"rMBE:  {rmbe_train:.4f}%")
print(f"rRMSD: {rrmsd_train:.4f}%")
print(f"rMAE:  {rmae_train:.4f}%")

plots(df_pred_train.index,
      df_pred_train['y_true'],
      df_pred_train['y_pred'],
      serie='Train')
# Out:
# === TEST (reconstruido) ===
# rMBE:  -0.2817%
# rRMSD: 12.3945%
# rMAE:  8.5248%
#
# === ENTRENAMIENTO (reconstruido) ===
# rMBE:  -0.1703%
# rRMSD: 10.9541%
# rMAE:  8.0946%
